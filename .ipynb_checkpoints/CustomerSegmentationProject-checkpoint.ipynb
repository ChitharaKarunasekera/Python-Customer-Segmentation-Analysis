# %% [markdown]
# # Customer Segmentation Project

# %% [markdown]
# This project is to analyze customer data to segment them based on purchasing behavior and demographics using clustering techniques. The outcome will be distinct customer profiles that can be used to reimagine marketing strategies.
#
# + Tools and Technologies:  Python, clustering algorithms, data preprocessing, data visualization, and Scikit-Learn.
#
# + Dataset: https://archive.ics.uci.edu/dataset/292/wholesale+customers `Wholesale Customers datase`

# %% [markdown]
# ## Load dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

# %%
# Load dataset
df = pd.read_csv(r"Wholesale customers data.csv")
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %% [markdown]
# Drop columns that are not needed

# %%
data = df.iloc[:,2:]
data.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Scatter Matrix
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha=0.3, figsize=(14, 8), diagonal='kde')
plt.show()

# %%
# Visualize distributions
data.hist(bins=30, figsize=(15, 10))
plt.show()

# %% [markdown]
# ### Identify Patterns and Relationships

# %% [markdown]
# #### Pair plot

# %%
# Pair plot
sns.pairplot(data)
plt.show()

# %% [markdown]
# #### Correlation heatmap

# %%
# Correlation heatmap
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Perform Elbow Method to find optimal number of clusters

# %%
# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
from sklearn.cluster import KMeans
wcss = [] # Within Cluster Sum of Square

# %%
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(2, 11), wcss, marker='o')
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('WCSS Values')
plt.show()

# %% [markdown]
# ## Training Model with K-Means Algorithm (Unsupervised Learning)

# %%
# Apply K-Means clustering with the optimal number of clusters
optimal_clusters = 4

# Apply K-Means
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
data['Cluster'] = kmeans.fit_predict(data_scaled)

# %% [markdown]
# + Evaluate using Silhouette score and other metrics

# %%
# Silhouette score
score = silhouette_score(data_scaled, data['Cluster'])
print('Silhouette Score:', score)
# Out:
# Silhouette Score: 0.40406527355371263

# %% [markdown]
# # Customer Profiling

# %% [markdown]
# ## Interpret Cluster Results
#
# + Analyze the characteristics of each cluster.

# %%
# Cluster centers
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[ 1.599589   -0.12182463 -0.22584555  1.0350249  -0.40151415  0.3385074 ]
#  [-0.30641752  1.81191562  2.20636776 -0.25003895  2.23347101  0.25168469]
#  [ 1.96681731  5.17550306  1.28721685  6.90059988 -0.55486198 16.47844745]
#  [-0.29742048 -0.23429882 -0.25385291 -0.2026929  -0.21533609 -0.15465161]]

# %%
# Convert the cluster centers into a DataFrame for better visualization
cluster_centers_df = pd.DataFrame(scaler.inverse_transform(centers), columns=data.columns)
print("Cluster Centers:\n", cluster_centers_df)

# Create descriptive profiles based on cluster characteristics
for i, center in enumerate(centers):
    print(f"\nCluster {i} Profile:")
    print("----------------------")
    for j, col in enumerate(data.columns):
        print(f"{col}: {center[j]:.2f}")

# Visualize clusters using a scatter plot for 'Frozen' and 'Detergents_Paper' features
sns.scatterplot(x=data['Frozen'], y=data['Detergents_Paper'], hue=data['Channels'], palette='viridis')
plt.xlabel('Frozen')
plt.ylabel('Detergents_Paper')
plt.title('Cluster Visualization: Frozen vs. Detergents_Paper')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Convert the cluster centers into a DataFrame for better visualization
# ----> 2 cluster_centers_df = pd.DataFrame(scaler.inverse_transform(centers), columns=data.columns)
#       3 print("Cluster Centers:\n", cluster_centers_df)
#       5 # Create descriptive profiles based on cluster characteristics
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     771         mgr = dict_to_mgr(
#     772             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     773             # attribute "name"
#    (...)
#     779             copy=_copy,
#     780         )
#     781     else:
# --> 782         mgr = ndarray_to_mgr(
#     783             data,
#     784             index,
#     785             columns,
#     786             dtype=dtype,
#     787             copy=copy,
#     788             typ=manager,
#     789         )
#     791 # For data is list-like, or Iterable (will consume into list)
#     792 elif is_list_like(data):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (4, 6), indices imply (4, 7)

# %% [markdown]
# ### Data Analysis Conclusion
#
# + Cluster 0 Profile: This cluster represents customers with moderate spending on fresh, milk, and frozen products, with lower spending on detergents/paper and delicatessen items.
#
# + Cluster 1 Profile: This cluster represents customers with very high spending across all categories, indicating possibly wholesale buyers or large institutions.
#
# + Cluster 2 Profile: This cluster represents customers with high spending on fresh products and moderate spending on other categories.
#
# + Cluster 3 Profile: This cluster represents customers with very high spending on milk and frozen products, indicating a preference for these categories.
#
# + Cluster 4 Profile: This cluster represents customers with extremely high spending on milk, frozen, and delicatessen items, likely indicating a specific business type or market segment.
#
#
# By analyzing the cluster centers, we can create meaningful customer profiles that describe the typical behavior of customers within each cluster. These profiles can then be used to tailor marketing strategies, identify target segments, and improve customer relationship management.
#
# You can now proceed to develop marketing strategies based on these customer profiles and recommend actionable insights for the business.

# %%
# Visualize clusters using a scatter plot for 'Frozen' and 'Detergents_Paper' features
sns.scatterplot(x=df['Frozen'], y=df['Detergents_Paper'], hue=df['Channel'], palette='viridis')
plt.xlabel('Frozen')
plt.ylabel('Detergents_Paper')
plt.title('Cluster Visualization: Frozen vs. Detergents_Paper')
plt.show()

# %%
# Visualize clusters using a scatter plot for 'Delicassen' and 'Milk' features
sns.scatterplot(x=df['Delicassen'], y=df['Milk'], hue=df['Channel'], palette='viridis')
plt.xlabel('Delicassen')
plt.ylabel('Milk')
plt.title('Cluster Visualization: Delicassen vs. Milk')
plt.show()
